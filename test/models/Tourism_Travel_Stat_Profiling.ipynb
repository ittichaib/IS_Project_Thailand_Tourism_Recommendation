# %%
import pandas as pd
import numpy as np

import sys
import os

# %%
parent_directory = os.path.abspath(os.path.join(os.getcwd(), '..', '..'))
sys.path.append(parent_directory)
print("Updated sys.path:", sys.path)
# Out:
# Updated sys.path: ['/opt/homebrew/Cellar/python@3.12/3.12.5/Frameworks/Python.framework/Versions/3.12/lib/python312.zip', '/opt/homebrew/Cellar/python@3.12/3.12.5/Frameworks/Python.framework/Versions/3.12/lib/python3.12', '/opt/homebrew/Cellar/python@3.12/3.12.5/Frameworks/Python.framework/Versions/3.12/lib/python3.12/lib-dynload', '', '/Users/ittichaiboonyarakthunya/Library/Caches/pypoetry/virtualenvs/is-project-thailand-tourism-recommendation-qwL-LsgH-py3.12/lib/python3.12/site-packages', '/Users/ittichaiboonyarakthunya/Documents/WorkDir/developments/IS_Project_Thailand_Tourism_Recommendation/utils', '/Users/ittichaiboonyarakthunya/Documents/WorkDir/developments/IS_Project_Thailand_Tourism_Recommendation']

# %%
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '../../utils')))

# %%
from utils.data_preparation import DataPreparation
from utils.constant import PROJECT_ROOT, REVIEWS_DATASET_DIR

DP = DataPreparation()
DP.check_nltk_path()
# Out:
# Numpy version: 1.26.4
# Pandas version: 2.2.0
# True

# %%
tourism_stat = pd.read_csv(f"{REVIEWS_DATASET_DIR}/tourism_statistic.csv")
tourism_stat_json = tourism_stat.to_json(orient='records', lines=True)

# %%
tourism_stat_json
# Out:
# '{"\\u0e20\\u0e32\\u0e04":"\\u0e01\\u0e23\\u0e38\\u0e07\\u0e40\\u0e17\\u0e1e\\u0e21\\u0e2b\\u0e32\\u0e19\\u0e04\\u0e23","\\u0e08\\u0e31\\u0e07\\u0e2b\\u0e27\\u0e31\\u0e14":"\\u0e01\\u0e23\\u0e38\\u0e07\\u0e40\\u0e17\\u0e1e\\u0e21\\u0e2b\\u0e32\\u0e19\\u0e04\\u0e23","\\u0e23\\u0e32\\u0e22\\u0e01\\u0e32\\u0e23":"\\u0e08\\u0e33\\u0e19\\u0e27\\u0e19\\u0e1c\\u0e39\\u0e49\\u0e40\\u0e22\\u0e35\\u0e48\\u0e22\\u0e21\\u0e40\\u0e22\\u0e37\\u0e2d\\u0e19","\\u0e23\\u0e32\\u0e22\\u0e01\\u0e32\\u0e23\\u0e22\\u0e48\\u0e2d\\u0e22":"\\u0e23\\u0e27\\u0e21","\\u0e1b\\u0e23\\u0e30\\u0e40\\u0e20\\u0e17\\u0e1c\\u0e39\\u0e49\\u0e40\\u0e22\\u0e35\\u0e48\\u0e22\\u0e21\\u0e40\\u0e22\\u0e37\\u0e2d\\u0e19":"\\u0e23\\u0e27\\u0e21","2554":"  43,763,002 ","2555":"  47,185,031 ","2556":"  50,568,902 ","2557":"  50,972,772 ","2558":"  56,515,597 ","2559":"  59,196,331 ","2560":"  63,575,737 ","2561":"  65,534,281 ","2562":"  66,966,562 ","2563":"  23,637,361 ","2564":"  13,706,439 ","2565":"  39,001,250 "}\n{"\\u0e20
# ...

# %%
from datasets import load_dataset

ds = load_dataset("Yelp/yelp_review_full")
# Out:
# ...
# Generating test split:   0%|          | 0/50000 [00:00<?, ? examples/s]

# %%
df_train = pd.DataFrame(ds['train'])
df_test = pd.DataFrame(ds['test'])

# Save to CSV (train and test data)
df_train.to_csv(f'{REVIEWS_DATASET_DIR}/yelp_review_train.csv', index=False)
df_test.to_csv(f'{REVIEWS_DATASET_DIR}/yelp_review_test.csv', index=False)

# %%
ds.to_csv(f"{REVIEWS_DATASET_DIR}/yelp_review_full.csv")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 ds.to_csv(f"{REVIEWS_DATASET_DIR}/yelp_review_full.csv")
#
# AttributeError: 'DatasetDict' object has no attribute 'to_csv'
